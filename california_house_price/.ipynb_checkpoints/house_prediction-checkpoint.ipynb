# %% [markdown]
# # Importing important libarires

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from tkinter import *

# %% [markdown]
# # Reading dataset

# %%
data=pd.read_csv('housing_price.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# # top 5 rows of dataframe

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# # bottom 5 rows of dataframe

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %% [markdown]
# # display all columns

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# # display all datatypes of columns

# %%
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # display shape of dataframe

# %%
data.shape
# Out:
# (20640, 10)

# %% [markdown]
# # display size of dataframe

# %%
data.size
# Out:
# 206400

# %% [markdown]
# # checking dublicate values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # checking null entries

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [raw]
# obs :here we seen in total bedrooms have some null values

# %% [markdown]
# # filling null values with mean

# %%
data['total_bedrooms'].fillna(value=data['total_bedrooms'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# # Statistical info

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.describe(include='number')
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.describe(exclude='number')
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %% [markdown]
# # numerical_segeration

# %%
num_col=data.select_dtypes(include='number').columns.to_list()

# %%
num_col
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %% [markdown]
# # Checking for outliers

# %% [markdown]
# # plot histogram and kde plot for all numerical columns

# %%
for col in num_col:
    fig, axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(data[col], kde=True, ax=axs[0])
    sns.kdeplot(data[col], ax=axs[1])
    print(f'Skewness of {col}: {data[col].skew()}')
# Out:
# Skewness of longitude: -0.2978012079524362
# Skewness of latitude: 0.46595300370997006
# Skewness of housing_median_age: 0.060330637599136865
# Skewness of total_rooms: 4.147343450632158
# Skewness of total_bedrooms: 3.4770233756335105
# Skewness of population: 4.93585822672712
# Skewness of households: 3.410437711667147
# Skewness of median_income: 1.6466567021344465
# Skewness of median_house_value: 0.9777632739098341

# %% [markdown]
# # to check outliers make boxplot

# %%
for col in num_col:
    plt.figure(figsize=(18,4))
    sns.boxplot(data,x=col)

# %% [raw]
# obs: Here we seen outlirers in total_rooms,total_bedrooms,population,households,median_income and median_house_value

# %%
df=data.copy()

# %%
cols=['total_rooms','total_bedrooms','population','households','median_income','median_house_value']

# %%
df[cols]
# Out:
#        total_rooms  total_bedrooms  population  households  median_income  \
# 0            880.0           129.0       322.0       126.0         8.3252
# 1           7099.0          1106.0      2401.0      1138.0         8.3014
# 2           1467.0           190.0       496.0       177.0         7.2574
# 3           1274.0           235.0       558.0       219.0         5.6431
# 4           1627.0           280.0       565.0       259.0         3.8462
# ...            ...             ...         ...         ...            ...
# 20635       1665.0           374.0       845.0       330.0         1.5603
# 20636        697.0           150.0       356.0       114.0         2.5568
# 20637       2254.0           485.0      1007.0       433.0         1.7000
# 20638       1860.0           409.0       741.0       349.0         1.8672
# 20639       2785.0           616.0      1387.0       530.0         2.3886
#
#        median_house_value
# 0                452600.0
# ...

# %%
df[cols].describe()
# Out:
#         total_rooms  total_bedrooms    population    households  \
# count  20640.000000    20640.000000  20640.000000  20640.000000
# mean    2635.763081      537.870553   1425.476744    499.539680
# std     2181.615252      419.266592   1132.462122    382.329753
# min        2.000000        1.000000      3.000000      1.000000
# 25%     1447.750000      297.000000    787.000000    280.000000
# 50%     2127.000000      438.000000   1166.000000    409.000000
# 75%     3148.000000      643.250000   1725.000000    605.000000
# max    39320.000000     6445.000000  35682.000000   6082.000000
#
#        median_income  median_house_value
# count   20640.000000        20640.000000
# mean        3.870671       206855.816909
# std         1.899822       115395.615874
# min         0.499900        14999.000000
# 25%         2.563400       119600.000000
# 50%         3.534800       179700.000000
# 75%         4.743250       264725.000000
# max        15.000100       500001.000000

# %% [markdown]
# # boxplot for outliers

# %%
for col in cols:
    plt.figure(figsize=(10,6))
    sns.boxplot(df,x=col)

# %% [markdown]
# # kde plot for outliers

# %%
for col in cols:
    plt.figure(figsize=(5,6))
    sns.kdeplot(df,x=col)

# %% [markdown]
# # slove outliers

# %%
lower_percentile = 10
upper_percentile = 90

# %%
def clip_outliers(df,col):
    # Calculate percentiles
    lower_threshold = df[col].quantile(lower_percentile / 100)
    upper_threshold = df[col].quantile(upper_percentile / 100)
    df[col] = df[col].clip(lower_threshold, upper_threshold)

# %%
for col in cols:
    clip_outliers(df,col)

# %%
for col in num_col:
    plt.figure(figsize=(3,4))
    sns.boxplot(x=col,data=df)

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# # plot subplot

# %%
for col in num_col:
    fig, axs = plt.subplots(1, 2, figsize=(10, 6))  

    sns.histplot(df[col], kde=False, ax=axs[0])  

    sns.kdeplot(df[col], ax=axs[1])
    
    print(f'Skewness of {col}: {df[col].skew()}')
# Out:
# Skewness of longitude: -0.2978012079524362
# Skewness of latitude: 0.46595300370997006
# Skewness of housing_median_age: 0.060330637599136865
# Skewness of total_rooms: 0.6318521182712542
# Skewness of total_bedrooms: 0.6557112065177939
# Skewness of population: 0.6378962067097287
# Skewness of households: 0.6357986606049864
# Skewness of median_income: 0.3921553131056896
# Skewness of median_house_value: 0.5588416417506866

# %% [markdown]
# # kde plot before and after solve outliers

# %%
for col in num_col:
    plt.figure(figsize=(5,6))
    sns.kdeplot(data[col],color='red')
    sns.kdeplot(df[col])

# %% [markdown]
# # co relation

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df[num_col].corr(),annot=True,fmt='0.1f')
plt.show()

# %%
df[num_col].corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.024011
# latitude            -0.924664  1.000000            0.011173    -0.023473
# housing_median_age  -0.108197  0.011173            1.000000    -0.377007
# total_rooms          0.024011 -0.023473           -0.377007     1.000000
# total_bedrooms       0.058319 -0.063447           -0.324383     0.902337
# population           0.116229 -0.132869           -0.307522     0.811848
# households           0.051909 -0.076719           -0.304376     0.900619
# median_income       -0.016146 -0.086558           -0.151312     0.257548
# median_house_value  -0.049956 -0.150276            0.096005     0.187741
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.058319    0.116229    0.051909      -0.016146
# latitude                 -0.063447   -0.132869   -0.076719      -0.086558
# ...

# %% [markdown]
# # Encoding

# %%
df.describe(exclude='number')
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        941.0           199.0
# 1        -122.22     37.86                21.0       4651.5           959.1
# 2        -122.24     37.85                52.0       1467.0           199.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        941.0           199.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
le= LabelEncoder()
df["ocean_proximity"]=le.fit_transform(df["ocean_proximity"])

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        941.0           199.0
# 1        -122.22     37.86                21.0       4651.5           959.1
# 2        -122.24     37.85                52.0       1467.0           199.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        941.0           199.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# # target column is price

# %%
df['median_house_value'].dtypes
# Out:
# dtype('float64')

# %%
df['median_house_value'].unique()
# Out:
# array([376600., 358500., 352100., ..., 251700., 349400., 200700.])

# %%
X = df.drop(['median_house_value'],axis=1)
y= df['median_house_value']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
st =StandardScaler()
X_train=st.fit_transform(X_train)
X_test=st.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.27258656, -1.3728112 ,  0.34849025, ...,  0.72846713,
#         -0.34809652,  2.00593172],
#        [ 0.70916212, -0.87669601,  1.61811813, ...,  1.32659024,
#          0.05379648,  2.00593172],
#        [-0.44760309, -0.46014647, -1.95271028, ..., -0.56221959,
#          0.30369847,  2.00593172],
#        ...,
#        [ 0.59946887, -0.75500738,  0.58654547, ...,  0.29673916,
#         -0.58447851, -0.81854604],
#        [-1.18553953,  0.90651045, -1.07984112, ...,  0.44064849,
#          1.43974218, -0.81854604],
#        [-1.41489815,  0.99543676,  1.85617335, ...,  1.92921052,
#         -0.84535643,  1.29981228]])

# %%
log = LinearRegression()
log.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.6162624777762039

# %%
print(mean_absolute_error(y_test, y_pred1))
# Out:
# 45465.20604025407

# %%
dt =DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred2 = dt.predict(X_test)

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.6665284441229167

# %%
mean_absolute_error(y_test,y_pred2)
# Out:
# 35033.21220930233

# %%
knn=KNeighborsRegressor()

# %%
param_grid = {
    'n_neighbors': [1,2,3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1, 2]
}

# %%
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 112 candidates, totalling 560 fits
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [1, 2, 3, 5, 7, 9, 11], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=2)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred3=grid_search.predict(X_test)

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.7442134354783848

# %%
final_data = pd.DataFrame({'Models':['LR','DT','Knn'],
             'ACC':[r2_score(y_test,y_pred1)*100,
                   r2_score(y_test,y_pred2)*100,
                   r2_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  61.626248
# 1     DT  66.652844
# 2    Knn  74.421344

# %%
sns.barplot(x=final_data['Models'],y=final_data['ACC'])
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %%
import joblib

# %%
joblib.dump(grid_search,'california_house_price')
# Out:
# ['california_house_price']

# %%
model = joblib.load('california_house_price')

# %%
import pandas as pd
new_data = pd.DataFrame({
    'longitude':-122.23,
    'latitude':37.88,
    'housing_median_age':41.0,
    'total_rooms':941.0,
    'total_bedrooms':199.0,
    'population':510.0,
    'households':184.0,
    'median_income':6.15921,
    'ocean_proximity':3,
    
     
},index=[0])

# %%
new_data
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        941.0           199.0
#
#    population  households  median_income  ocean_proximity
# 0       510.0       184.0        6.15921                3

# %%
p = model.predict(new_data)

# %%
p
# Out:
# array([343620.00378877])

# %% [markdown]
# # GUI

# %%
from tkinter import *

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    p9=float(e9.get()) 
    df = pd.DataFrame({
    'longitude':p1,
    'latitude':p2,
    'housing_median_age':p3,
    'total_rooms':p4,
    'total_bedrooms':p5,
    'population':p6,
    'households':p7,
    'median_income':p8,
    'ocean_proximity':p9,   
     
},index=[0])
    model = joblib.load('california_house_price')
    result=model.predict(df)
    
    
    Label(master, text=round(result[0])).grid(row=31)
   
    
    
    
master = Tk()
master.title("california_house_price Using Machine Learning")


label = Label(master, text = "california_house_price Using Machine Learning"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)


Label(master, text="longitude").grid(row=1)
Label(master, text="latitude").grid(row=2)
Label(master, text="housing_median_age").grid(row=3)
Label(master, text="total_rooms").grid(row=4)
Label(master, text="total_bedrooms").grid(row=5)
Label(master, text="population").grid(row=6)
Label(master, text="households").grid(row=7)
Label(master, text="median_income").grid(row=8)
Label(master, text="ocean_proximity").grid(row=9)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)




e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)


Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()
