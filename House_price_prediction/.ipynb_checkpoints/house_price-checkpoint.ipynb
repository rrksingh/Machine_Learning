# %% [markdown]
# # Importing important libaries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from tkinter import *

# %% [markdown]
# # Reading dataset

# %%
data=pd.read_csv('Housing.csv')

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# # Top 5 rows of dataframe

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# # Bottom 5 rows of dataframe

# %%
data.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %% [markdown]
# # display all columns

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# # Display all datatypes of columns

# %%
data.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# # Display shape of dataframe

# %%
data.shape
# Out:
# (545, 13)

# %% [markdown]
# # check duplicate values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Checking Null entries

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # Statistical info

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.describe(include='number')
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.describe(exclude='number')
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %% [markdown]
# # numerical segeration

# %%
num_col=data.select_dtypes(include='number').columns.to_list()

# %%
num_col
# Out:
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %% [markdown]
# # Checking for outliers

# %% [markdown]
# ## histogram and kde plot for all numberical columns

# %%
for col in num_col:
    fig, axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(data[col], kde=True, ax=axs[0])
    sns.kdeplot(data[col], ax=axs[1])
    print(f'Skewness of {col}: {data[col].skew()}')
# Out:
# Skewness of price: 1.2122388370279802
# Skewness of area: 1.321188343153483
# Skewness of bedrooms: 0.49568394074553473
# Skewness of bathrooms: 1.5892635781317528
# Skewness of stories: 1.0820882904085742
# Skewness of parking: 0.8420623343734072

# %%
for col in num_col:
    plt.figure(figsize=(18,4))
    sns.boxplot(data,x=col)

# %%
df=data.copy()

# %%
lower_percentile = 10
upper_percentile = 90

# %%
def clip_outliers(df,col):
    # Calculate percentiles
    lower_threshold = df[col].quantile(lower_percentile / 100)
    upper_threshold = df[col].quantile(upper_percentile / 100)
    df[col] = df[col].clip(lower_threshold, upper_threshold)

# %%
for col in num_col:
    clip_outliers(df,col)

# %%
df.shape
# Out:
# (545, 13)

# %%
for col in num_col:
    plt.figure(figsize=(3,4))
    sns.boxplot(x=col,data=df)

# %%
for col in num_col:
    fig, axs = plt.subplots(1, 2, figsize=(10, 6))  

    sns.histplot(df[col], kde=False, ax=axs[0])  

    sns.kdeplot(df[col], ax=axs[1])
    
    print(f'Skewness of {col}: {df[col].skew()}')
# Out:
# Skewness of price: 0.524323001543533
# Skewness of area: 0.44915415670629333
# Skewness of bedrooms: 0.06545375161356755
# Skewness of bathrooms: 1.0724512564755693
# Skewness of stories: 0.4285627733584683
# Skewness of parking: 0.6685173813282207

# %%
for col in num_col:
    plt.figure(figsize=(5,6))
    sns.kdeplot(data[col],color='red')
    sns.kdeplot(df[col])

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df[num_col].corr(),annot=True,fmt='0.1f')
plt.show()

# %%
df[num_col].corr()
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.589856  0.382607   0.508701  0.398878  0.368024
# area       0.589856  1.000000  0.181198   0.214084  0.073007  0.360658
# bedrooms   0.382607  0.181198  1.000000   0.374939  0.476998  0.151413
# bathrooms  0.508701  0.214084  0.374939   1.000000  0.308015  0.165313
# stories    0.398878  0.073007  0.476998   0.308015  1.000000  0.008763
# parking    0.368024  0.360658  0.151413   0.165313  0.008763  1.000000

# %% [markdown]
# # encoding

# %%
cat_col=data.select_dtypes(exclude='number').columns.to_list()

# %%
cat_col
# Out:
# ['mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'prefarea',
#  'furnishingstatus']

# %%
le= LabelEncoder()
for col in cat_col:
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    7350000  7420         4          2        3         1          0
# 1    7350000  7980         4          2        3         1          0
# 2    7350000  7980         3          2        2         1          0
# 3    7350000  7500         4          2        2         1          0
# 4    7350000  7420         4          1        2         1          1
# ..       ...   ...       ...        ...      ...       ...        ...
# 540  2835000  3000         2          1        1         1          0
# 541  2835000  3000         3          1        1         0          0
# 542  2835000  3620         2          1        1         1          0
# 543  2835000  3000         3          1        1         0          0
# 544  2835000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df['price'].dtypes
# Out:
# dtype('int64')

# %%
df['price'].unique()
# Out:
# array([7350000, 7343000, 7245000, 7210000, 7140000, 7070000, 7035000,
#        7000000, 6930000, 6895000, 6860000, 6790000, 6755000, 6720000,
#        6685000, 6650000, 6629000, 6615000, 6580000, 6510000, 6475000,
#        6440000, 6419000, 6405000, 6300000, 6293000, 6265000, 6230000,
#        6195000, 6160000, 6125000, 6107500, 6090000, 6083000, 6020000,
#        5950000, 5943000, 5880000, 5873000, 5866000, 5810000, 5803000,
#        5775000, 5740000, 5652500, 5600000, 5565000, 5530000, 5523000,
#        5495000, 5460000, 5425000, 5390000, 5383000, 5320000, 5285000,
#        5250000, 5243000, 5229000, 5215000, 5145000, 5110000, 5075000,
#        5040000, 5033000, 5005000, 4970000, 4956000, 4935000, 4907000,
#        4900000, 4893000, 4865000, 4830000, 4795000, 4767000, 4760000,
#        4753000, 4690000, 4655000, 4620000, 4613000, 4585000, 4550000,
#        4543000, 4515000, 4480000, 4473000, 4445000, 4410000, 4403000,
# ...

# %%
X = df.drop(['price'],axis=1)
y= df['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
st =StandardScaler()
X_train=st.fit_transform(X_train)
X_test=st.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.5986646 ,  0.09573335,  1.72152153, ...,  0.41409817,
#         -0.55262032, -1.40940148],
#        [ 1.32473751,  0.09573335,  1.72152153, ...,  1.65072012,
#         -0.55262032, -0.07931697],
#        [-0.7227881 , -1.39497166, -0.5808815 , ...,  1.65072012,
#         -0.55262032, -1.40940148],
#        ...,
#        [-0.30892654,  0.09573335,  1.72152153, ...,  0.41409817,
#         -0.55262032, -1.40940148],
#        [-0.58725449, -1.39497166, -0.5808815 , ..., -0.82252377,
#         -0.55262032,  1.25076755],
#        [ 0.29613422,  0.09573335,  1.72152153, ...,  0.41409817,
#         -0.55262032, -0.07931697]])

# %%
log = LinearRegression()
log.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.6719978258560116

# %%
print(mean_absolute_error(y_test, y_pred1))
# Out:
# 726099.5097367659

# %%
dt =DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred2 = dt.predict(X_test)

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.42815998316090287

# %%
mean_absolute_error(y_test,y_pred2)
# Out:
# 859330.2752293578

# %% [markdown]
# # KNN algorithm

# %%
knn=KNeighborsRegressor(n_neighbors=10)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=13)

# %%
y_pred3=knn.predict(X_test)

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.6532267946145958

# %%
final_data = pd.DataFrame({'Models':['LR','DT','Knn'],
             'ACC':[r2_score(y_test,y_pred1)*100,
                   r2_score(y_test,y_pred2)*100,
                   r2_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  67.199783
# 1     DT  43.155490
# 2    Knn  62.876402

# %%
sns.barplot(x=final_data['Models'],y=final_data['ACC'])
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# obs:here we seen lr hax most predictable ..

# %%
import joblib

# %%
joblib.dump(log,'house_price_prediction')
# Out:
# ['house_price_prediction']

# %%
model = joblib.load('house_price_prediction')

# %%
import pandas as pd
new_data = pd.DataFrame({
    'area':7420,
    'bedrooms':4,
    'bathrooms':2,
    'stories':3,
    'mainroad':1,
    'guestroom':0,
    'basement':0,
    'hotwaterheating':0,
    'airconditioning':1,
    'parking':2,
    'prefarea':1,
    'furnishingstatus':0,
     
},index=[0])

# %%
new_data
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                1        2         1                 0

# %%
p = model.predict(new_data)

# %%
print(round(p[0]))
# Out:
# 3642813062

# %%
import pandas as pd
new_data = pd.DataFrame({
    'area':3850,
    'bedrooms':3,
    'bathrooms':1,
    'stories':2,
    'mainroad':1,
    'guestroom':0,
    'basement':0,
    'hotwaterheating':0,
    'airconditioning':0,
    'parking':0,
    'prefarea':0,
    'furnishingstatus':2,
     
},index=[0])

# %%
p = model.predict(new_data)

# %%
print(round(p[0]))
# Out:
# 1891917160

# %% [markdown]
# # Gui

# %%
from tkinter import *

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    p9=float(e9.get()) 
    p10=float(e10.get())
    p11=float(e11.get())
    p12=float(e12.get())
    df = pd.DataFrame({
    'area':p1,
    'bedrooms':p2,
    'bathrooms':p3,
    'stories':p4,
    'mainroad':p5,
    'guestroom':p6,
    'basement':p7,
    'hotwaterheating':p8,
    'airconditioning':p9,
    'parking':p10,
    'prefarea':p11,
    'furnishingstatus':p12,    
     
},index=[0])
    model = joblib.load('house_price_prediction')
    result=model.predict(df)
    
    
    Label(master, text=round(result[0])).grid(row=31)
   
    
    
    
master = Tk()
master.title("house_price_prediction Using Machine Learning")


label = Label(master, text = "house_price_prediction Using Machine Learning"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)


Label(master, text="area").grid(row=1)
Label(master, text="bedrooms").grid(row=2)
Label(master, text="bathrooms").grid(row=3)
Label(master, text="stories").grid(row=4)
Label(master, text="mainroad").grid(row=5)
Label(master, text="guestroom").grid(row=6)
Label(master, text="basement").grid(row=7)
Label(master, text="hotwaterheating").grid(row=8)
Label(master, text="airconditioning").grid(row=9)
Label(master, text="parking").grid(row=10)
Label(master,text="prefarea").grid(row=11)
Label(master,text="furnishingstatus").grid(row=12)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)
e10 = Entry(master)
e11 = Entry(master)
e12 = Entry(master)




e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10,column=1)
e11.grid(row=11,column=1)
e12.grid(row=12,column=1)


Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()
