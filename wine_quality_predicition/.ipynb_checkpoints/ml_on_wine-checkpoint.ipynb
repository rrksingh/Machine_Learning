# %% [markdown]
# # Importing important libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from tkinter import *

# %% [markdown]
# # Reading Dataset

# %%
data=pd.read_csv('winequality.csv')

# %% [markdown]
# # top 5 rows of dataframe

# %%
data.head(80)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# ..            ...               ...          ...             ...        ...
# 75            8.8             0.410         0.64             2.2      0.093
# 76            8.8             0.410         0.64             2.2      0.093
# 77            6.8             0.785         0.00             2.4      0.104
# 78            6.7             0.750         0.12             2.0      0.086
# 79            8.3             0.625         0.20             1.5      0.080
#
# ...

# %% [markdown]
# # bottom 5 rows of dataframe

# %%
data.tail(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1549            7.4             0.360         0.30             1.8      0.074
# 1550            7.1             0.680         0.00             2.3      0.087
# 1551            7.1             0.670         0.00             2.3      0.083
# 1552            6.3             0.680         0.01             3.7      0.103
# 1553            7.3             0.735         0.00             2.2      0.080
# 1554            6.6             0.855         0.02             2.4      0.062
# 1555            7.0             0.560         0.17             1.7      0.065
# 1556            6.6             0.880         0.04             2.2      0.066
# 1557            6.6             0.855         0.02             2.4      0.062
# 1558            6.9             0.630         0.33             6.7      0.235
# 1559            7.8             0.600         0.26             2.0      0.080
# ...

# %% [markdown]
# # display of all columns name

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # display all datatypes of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# # display shape of dataframe

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# # Checking duplicate entries

# %%
data.duplicated().sum()
# Out:
# 240

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# # Statistical info

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %% [markdown]
# # Numerical columns

# %%
data.describe(include='number')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %% [markdown]
# # Checking null entries

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [raw]
# obs:there is no null entries

# %% [markdown]
# # Numerical segeration

# %%
num_col=data.select_dtypes(include='number').columns.to_list()

# %%
num_col
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# # Checking for outliers

# %% [markdown]
# ## Histogram and kde plot for all numerical columns

# %%
for col in num_col:
    fig, axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(data[col], kde=True, ax=axs[0])
    sns.kdeplot(data[col], ax=axs[1])
    print(f'Skewness of {col}: {data[col].skew()}')
# Out:
# Skewness of fixed acidity: 0.9410413664561449
# Skewness of volatile acidity: 0.7292789463991854
# Skewness of citric acid: 0.31272554238899036
# Skewness of residual sugar: 4.548153403940447
# Skewness of chlorides: 5.502487294623722
# Skewness of free sulfur dioxide: 1.2265794991760643
# Skewness of total sulfur dioxide: 1.5403680777213933
# Skewness of density: 0.04477785573116107
# Skewness of pH: 0.2320322752014824
# Skewness of sulphates: 2.4065046145674196
# Skewness of alcohol: 0.8598411692032926
# Skewness of quality: 0.19240658731658308

# %%
for col in num_col:
    plt.figure(figsize=(18,4))
    sns.boxplot(data,x=col)

# %% [raw]
# obs: in this plots all columns have outliers

# %% [markdown]
# # boxplot for outliers

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data,x='fixed acidity')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='volatile acidity')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='citric acid')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='residual sugar')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='chlorides')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='free sulfur dioxide')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='total sulfur dioxide')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='density')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='pH')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='sulphates')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='alcohol')

plt.figure(figsize=(8,4))
sns.boxplot(data,x='quality')
# Out:
# <Axes: xlabel='quality'>

# %%
df=data.copy()

# %%
lower_percentile = 10
upper_percentile = 90

# %%
def clip_outliers(df,col):
    # Calculate percentiles
    lower_threshold = df[col].quantile(lower_percentile / 100)
    upper_threshold = df[col].quantile(upper_percentile / 100)
    df[col] = df[col].clip(lower_threshold, upper_threshold)

# %%
for col in df.columns:
    clip_outliers(df,col)

# %%
df.shape
# Out:
# (1359, 12)

# %%
for col in df.columns:
    plt.figure(figsize=(3,4))
    sns.boxplot(x=col,data=df)

# %%
for col in df.columns:
    fig, axs = plt.subplots(1, 2, figsize=(10, 6))  

    sns.histplot(df[col], kde=False, ax=axs[0])  

    sns.kdeplot(df[col], ax=axs[1])
    
    print(f'Skewness of {col}: {df[col].skew()}')
# Out:
# Skewness of fixed acidity: 0.5045071929031691
# Skewness of volatile acidity: 0.1169124321548323
# Skewness of citric acid: 0.037460507930183566
# Skewness of residual sugar: 0.8528662192878069
# Skewness of chlorides: 0.4743311976564438
# Skewness of free sulfur dioxide: 0.5284602883869456
# Skewness of total sulfur dioxide: 0.6423131843802222
# Skewness of density: 0.07002283198463716
# Skewness of pH: 0.06462080160864334
# Skewness of sulphates: 0.5188535803000153
# Skewness of alcohol: 0.4764636198688068
# Skewness of quality: 0.5749418683844707

# %%
for col in df.columns:
    plt.figure(figsize=(5,6))
    sns.kdeplot(data[col],color='red')
    sns.kdeplot(df[col])

# %% [markdown]
# # Get overall Statistics About the Dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.240177          0.521538     0.264260        2.324474
# std         1.365331          0.147208     0.178218        0.542642
# min         6.500000          0.310000     0.010000        1.700000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        10.700000          0.760000     0.530000        3.460000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.081174            15.273363             44.487491     0.996720
# std       0.015122             8.599915             26.452117     0.001437
# ...

# %% [markdown]
# # Quality vs fixed Acidity

# %%
plt.bar(data['quality'],data['fixed acidity'])
plt.xlabel('Quality',color='blue')
plt.ylabel('Fixed acidity',color='red')
plt.show()

# %% [markdown]
# # volatile acidity vs quality

# %%
plt.bar(data['quality'],data['volatile acidity'])
plt.xlabel('Quality')
plt.ylabel('Volatile acidity')
plt.show()

# %% [markdown]
# # Residual sugar vs quality

# %%
plt.bar(data['quality'],data['residual sugar'])
plt.xlabel('Quality')
plt.ylabel('residual sugar')
plt.show()

# %% [markdown]
# # correlation matrix

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,fmt='0.1f')
plt.show()

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.296486     0.676168
# volatile acidity          -0.296486          1.000000    -0.616573
# citric acid                0.676168         -0.616573     1.000000
# residual sugar             0.210368          0.031329     0.162744
# chlorides                  0.206333          0.155134     0.122482
# free sulfur dioxide       -0.147227         -0.001254    -0.045078
# total sulfur dioxide      -0.101547          0.099691     0.025141
# density                    0.625118          0.029460     0.341637
# pH                        -0.685526          0.252448    -0.551489
# sulphates                  0.244704         -0.325709     0.344687
# alcohol                   -0.018574         -0.238465     0.121630
# quality                    0.138203         -0.374597     0.219799
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# # Encoding of target variable

# %%
df['quality'].dtypes
# Out:
# dtype('int64')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7], dtype=int64)

# %%
df['quality']=[1 if x>=7 else 0 for x in df['quality']]

# %%
df['quality'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # Checking for imbalanced dataset

# %%
df['quality'].value_counts()
# Out:
# quality
# 0    1175
# 1     184
# Name: count, dtype: int64

# %%
sns.countplot(x=df['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# # Handling imbalanced dataset
#
#
# #### SMOTE (Synthetic Minority Over-sampling Technique) is an effective oversampling method used to address class imbalance in classification datasets. When dealing with imbalanced data, where the minority class has significantly fewer examples than the majority class, SMOTE helps balance the class distribution by creating synthetic samples for the minority class.
#
# Here’s how SMOTE works:
#
# It generates new synthetic examples by interpolating between existing minority-class samples.
# For each minority-class instance, SMOTE selects its k nearest neighbors (usually k=5).
# It creates new synthetic instances by combining the features of the original instance and its neighbors.
# SMOTE is particularly useful when:
#
# You want to avoid overfitting caused by random oversampling (simply duplicating minority-class examples).
# You need to improve the model’s performance on the minority class.
# Remember that SMOTE is just one of several techniques for handling class imbalance, and it can significantly enhance the performance of machine learning models when applied correctly

# %%
from imblearn.over_sampling import SMOTE

# %%
X = df.drop(['quality'],axis=1)
y= df['quality']
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y.value_counts()
# Out:
# quality
# 0    1175
# 1     184
# Name: count, dtype: int64

# %%
y_res.value_counts()
# Out:
# quality
# 0    1175
# 1    1175
# Name: count, dtype: int64

# %% [markdown]
# # Splitting the dataset into the Training set and test set

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
st =StandardScaler()
X_train=st.fit_transform(X_train)
X_test=st.transform(X_test)

# %%
X_train
# Out:
# array([[-0.87201886,  1.05648218, -1.44849583, ...,  0.88131422,
#         -1.17868312, -0.67890481],
#        [ 1.02015582,  2.01798589, -0.30643329, ...,  0.93507299,
#         -0.08330168,  0.42541054],
#        [ 1.60630508, -0.4079862 ,  1.03379986, ..., -0.78593409,
#          1.55308174,  0.53071169],
#        ...,
#        [-0.73829196,  0.87635196, -0.24816229, ..., -0.09753126,
#         -1.08331377, -1.04880569],
#        [-1.1779039 , -0.0512256 , -1.2970404 , ..., -0.01148091,
#         -0.26512206, -1.25940801],
#        [ 0.36073791, -1.12150741,  0.04319275, ..., -1.13013551,
#         -1.17422396, -0.41699874]])

# %% [markdown]
# # Logistic Regression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.8404255319148937

# %%
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       232
#            1       0.81      0.90      0.85       238
#
#     accuracy                           0.84       470
#    macro avg       0.85      0.84      0.84       470
# weighted avg       0.84      0.84      0.84       470

# %%
print(confusion_matrix(y_test, y_pred1))
# Out:
# [[181  51]
#  [ 24 214]]

# %% [markdown]
# # Decision Tree Algorithm

# %%
dt =DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8553191489361702

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8512396694214877

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.8583333333333334

# %%
print(confusion_matrix(y_test, y_pred2))
# Out:
# [[196  36]
#  [ 32 206]]

# %%
final_data = pd.DataFrame({'Models':['LR','DT'],
             'ACC':[accuracy_score(y_test,y_pred1)*100,
                   accuracy_score(y_test,y_pred2)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  84.042553
# 1     DT  85.531915

# %%
sns.barplot(x=final_data['Models'],y=final_data['ACC'])
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # Save the Model

# %%
import joblib

# %%
joblib.dump(dt,'wine_quality')
# Out:
# ['wine_quality']

# %%
model = joblib.load('wine_quality')

# %% [markdown]
# # Prediction on new data

# %%
import pandas as pd
new_data = pd.DataFrame({
    'fixed acidity':7.3,
    'volatile acidity':0.65,
    'citric acid':0.00,
    'residual sugar':1.2,
    'chlorides':0.065,
    'free sulfur dioxide':15.0,
    'total sulfur dioxide':21.0,
    'density':0.9946,
    'pH':3.39,
    'sulphates':0.47,
    'alcohol':10.0,
     
},index=[0])

# %%
new_data
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.3              0.65          0.0             1.2      0.065
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 15.0                  21.0   0.9946  3.39       0.47
#
#    alcohol
# 0     10.0

# %%
p = model.predict(new_data)

# %%
if p[0] == 1: 
    print("Good Quality Wine")
else:
    print("Bad Quality Wine")
# Out:
# Good Quality Wine

# %% [markdown]
# # GUI

# %%
from tkinter import *

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    p9=float(e9.get()) 
    p10=float(e10.get())
    p11=float(e11.get())
    df = pd.DataFrame({
    'fixed acidity':p1,
    'volatile acidity':p2,
    'citric acid':p3,
    'residual sugar':p4,
    'chlorides':p5,
    'free sulfur dioxide':p6,
    'total sulfur dioxide':p7,
    'density':p8,
    'pH':p9,
    'sulphates':p10,
    'alcohol':p11,
     
},index=[0])
    model = joblib.load('wine_quality')
    result=model.predict(df)
    
    if result[0] == 0:
        Label(master, text="Bad Quality Wine").grid(row=31)
    else:
        Label(master, text="Good Quality Wine").grid(row=31)
    
    
master = Tk()
master.title("Wine Quality Prediction Using Machine Learning")


label = Label(master, text = "Wine Quality Prediction Using ML"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)


Label(master, text="fixed acidity").grid(row=1)
Label(master, text="volatile acidity").grid(row=2)
Label(master, text="citric acid").grid(row=3)
Label(master, text="residual sugar").grid(row=4)
Label(master, text="chlorides").grid(row=5)
Label(master, text="free sulfur dioxide").grid(row=6)
Label(master, text="total sulfur dioxide").grid(row=7)
Label(master, text="density").grid(row=8)
Label(master, text="pH").grid(row=9)
Label(master, text="sulphates").grid(row=10)
Label(master,text="alcohol").grid(row=11)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)
e10 = Entry(master)
e11 = Entry(master)



e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10,column=1)
e11.grid(row=11,column=1)


Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()
